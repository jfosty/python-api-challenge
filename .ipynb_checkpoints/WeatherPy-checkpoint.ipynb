# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#pip install citipy - already imported library, shouldn't need to again

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | 'ibri
# City not found. Skipping...
# Processing Record 4 of Set 1 | bahia honda
# Processing Record 5 of Set 1 | tura
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | buka
# Processing Record 9 of Set 1 | badger
# Processing Record 10 of Set 1 | west island
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | afaahiti
# Processing Record 13 of Set 1 | hammerfest
# Processing Record 14 of Set 1 | kulia village
# City not found. Skipping...
# Processing Record 15 of Set 1 | magadan
# Processing Record 16 of Set 1 | uturoa
# Processing Record 17 of Set 1 | flying fish cove
# Processing Record 18 of Set 1 | qaqortoq
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | port mathurin
# Processing Record 21 of Set 1 | tazovsky
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | tan-tan
# Processing Record 24 of Set 1 | nar'yan-mar
# Processing Record 25 of Set 1 | nuuk
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | stanley
# Processing Record 28 of Set 1 | beloyarskiy
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | campbellton
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | naldurg
# Processing Record 34 of Set 1 | puerto natales
# Processing Record 35 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | enewetak
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | hawaiian paradise park
# Processing Record 40 of Set 1 | fayetteville
# Processing Record 41 of Set 1 | san antonio de pale
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | al ghayzah
# Processing Record 47 of Set 1 | 'ain el hadjel
# City not found. Skipping...
# Processing Record 48 of Set 1 | saipan
# Processing Record 49 of Set 1 | puerto aysen
# Processing Record 50 of Set 1 | grytviken
# Processing Record 0 of Set 2 | edinburgh of the seven seas
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | mirny
# Processing Record 3 of Set 2 | kyain seikgyi township
# City not found. Skipping...
# Processing Record 4 of Set 2 | dumai
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | yigo village
# Processing Record 7 of Set 2 | caala
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | touros
# Processing Record 10 of Set 2 | bahraigh
# Processing Record 11 of Set 2 | vilyuysk
# Processing Record 12 of Set 2 | weno
# Processing Record 13 of Set 2 | westport
# Processing Record 14 of Set 2 | kerikeri
# Processing Record 15 of Set 2 | susuman
# Processing Record 16 of Set 2 | yerofey pavlovich
# Processing Record 17 of Set 2 | cill airne
# Processing Record 18 of Set 2 | fisterra
# Processing Record 19 of Set 2 | warrensburg
# Processing Record 20 of Set 2 | talnakh
# Processing Record 21 of Set 2 | loomis
# Processing Record 22 of Set 2 | mil'kovo
# Processing Record 23 of Set 2 | aasiaat
# Processing Record 24 of Set 2 | urengoy
# Processing Record 25 of Set 2 | darwin
# Processing Record 26 of Set 2 | shangri-la
# City not found. Skipping...
# Processing Record 27 of Set 2 | san jose village
# City not found. Skipping...
# Processing Record 28 of Set 2 | alice springs
# Processing Record 29 of Set 2 | san rafael
# Processing Record 30 of Set 2 | la mira
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | sao vicente
# Processing Record 35 of Set 2 | ugoofaaru
# Processing Record 36 of Set 2 | blackmans bay
# Processing Record 37 of Set 2 | bokoro
# Processing Record 38 of Set 2 | papatowai
# Processing Record 39 of Set 2 | port hedland
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | santa vitoria do palmar
# Processing Record 17 of Set 4 | south hedland
# Processing Record 18 of Set 4 | tazacorte
# Processing Record 19 of Set 4 | nuku'alofa
# Processing Record 20 of Set 4 | mata-utu
# Processing Record 21 of Set 4 | nevel'sk
# Processing Record 22 of Set 4 | anadyr
# Processing Record 23 of Set 4 | turinskaya sloboda
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | dudinka
# Processing Record 26 of Set 4 | punta arenas
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | chonchi
# Processing Record 29 of Set 4 | minas de marcona
# Processing Record 30 of Set 4 | xilin hot
# Processing Record 31 of Set 4 | malvan
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | joinville
# Processing Record 34 of Set 4 | vernon
# Processing Record 35 of Set 4 | sisimiut
# Processing Record 36 of Set 4 | minot air force base
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | ambon
# Processing Record 39 of Set 4 | yagry
# City not found. Skipping...
# Processing Record 40 of Set 4 | xai-xai
# Processing Record 41 of Set 4 | alo
# Processing Record 42 of Set 4 | sao jose da coroa grande
# Processing Record 43 of Set 4 | barcelos
# Processing Record 44 of Set 4 | howrah
# Processing Record 45 of Set 4 | toliara
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | mossel bay
# Processing Record 48 of Set 4 | rouyn-noranda
# Processing Record 49 of Set 4 | oranjemund
# Processing Record 0 of Set 5 | fortuna
# Processing Record 1 of Set 5 | svetlogorsk
# Processing Record 2 of Set 5 | thaba-tseka
# Processing Record 3 of Set 5 | vila do maio
# Processing Record 4 of Set 5 | lubz
# Processing Record 5 of Set 5 | la sarre
# Processing Record 6 of Set 5 | phan rang-thap cham
# Processing Record 7 of Set 5 | trincomalee
# Processing Record 8 of Set 5 | sinop
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | chicxulub puerto
# City not found. Skipping...
# Processing Record 11 of Set 5 | long eaton
# Processing Record 12 of Set 5 | chulakkurgan
# Processing Record 13 of Set 5 | kingston
# Processing Record 14 of Set 5 | nova sintra
# Processing Record 15 of Set 5 | lepsy
# Processing Record 16 of Set 5 | cidreira
# Processing Record 17 of Set 5 | svetlyy
# Processing Record 18 of Set 5 | dryden
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | tukums
# Processing Record 21 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 5 | gadzhiyevo
# Processing Record 23 of Set 5 | lauro de freitas
# Processing Record 24 of Set 5 | lihue
# Processing Record 25 of Set 5 | nabire
# Processing Record 26 of Set 5 | plastun
# Processing Record 27 of Set 5 | walvis bay
# Processing Record 28 of Set 5 | st. john's
# Processing Record 29 of Set 5 | gilgit
# Processing Record 30 of Set 5 | akureyri
# Processing Record 31 of Set 5 | baruun-urt
# Processing Record 32 of Set 5 | heyuan
# Processing Record 33 of Set 5 | winnemucca
# Processing Record 34 of Set 5 | laojunmiao
# Processing Record 35 of Set 5 | ust'-ilimsk
# Processing Record 36 of Set 5 | atafu village
# Processing Record 37 of Set 5 | bandon
# Processing Record 38 of Set 5 | la passe
# Processing Record 39 of Set 5 | fairmont
# Processing Record 40 of Set 5 | an nimas
# Processing Record 41 of Set 5 | knyaze-volkonskoye
# Processing Record 42 of Set 5 | pemangkat
# Processing Record 43 of Set 5 | talcahuano
# Processing Record 44 of Set 5 | auki
# Processing Record 45 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 5 | invercargill
# Processing Record 47 of Set 5 | shakawe
# Processing Record 48 of Set 5 | newman
# Processing Record 49 of Set 5 | otaki
# Processing Record 0 of Set 6 | alesund
# Processing Record 1 of Set 6 | tabou
# Processing Record 2 of Set 6 | mount pearl
# Processing Record 3 of Set 6 | waingapu
# Processing Record 4 of Set 6 | ingeniero guillermo n. juarez
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | fort st. john
# Processing Record 7 of Set 6 | sao jose de piranhas
# Processing Record 8 of Set 6 | fale old settlement
# Processing Record 9 of Set 6 | smithers
# Processing Record 10 of Set 6 | dapa
# Processing Record 11 of Set 6 | garoowe
# Processing Record 12 of Set 6 | uruguaiana
# Processing Record 13 of Set 6 | greymouth
# Processing Record 14 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 15 of Set 6 | colac
# Processing Record 16 of Set 6 | hilo
# Processing Record 17 of Set 6 | wailua homesteads
# Processing Record 18 of Set 6 | naze
# Processing Record 19 of Set 6 | cozumel
# Processing Record 20 of Set 6 | yabelo
# Processing Record 21 of Set 6 | alpu
# Processing Record 22 of Set 6 | yaypan
# Processing Record 23 of Set 6 | xianyang
# Processing Record 24 of Set 6 | chibougamau
# Processing Record 25 of Set 6 | coquimbo
# Processing Record 26 of Set 6 | i-n-salah
# Processing Record 27 of Set 6 | chos malal
# Processing Record 28 of Set 6 | klyuchi
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | tokar
# Processing Record 31 of Set 6 | lindale
# Processing Record 32 of Set 6 | amparafaravola
# Processing Record 33 of Set 6 | rongelap
# Processing Record 34 of Set 6 | lennox head
# City not found. Skipping...
# Processing Record 35 of Set 6 | santana
# Processing Record 36 of Set 6 | sinabang
# Processing Record 37 of Set 6 | dire dawa
# Processing Record 38 of Set 6 | dompu
# Processing Record 39 of Set 6 | vilyuchinsk
# Processing Record 40 of Set 6 | posse
# Processing Record 41 of Set 6 | koungou
# Processing Record 42 of Set 6 | miranda do douro
# Processing Record 43 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 44 of Set 6 | thunder bay
# Processing Record 45 of Set 6 | aburi
# Processing Record 46 of Set 6 | tralee
# Processing Record 47 of Set 6 | pimenta bueno
# Processing Record 48 of Set 6 | kuchinarai
# Processing Record 49 of Set 6 | constantia
# Processing Record 0 of Set 7 | korla
# Processing Record 1 of Set 7 | mogocha
# Processing Record 2 of Set 7 | puerto ayacucho
# Processing Record 3 of Set 7 | monrovia
# Processing Record 4 of Set 7 | xiaoweizhai
# Processing Record 5 of Set 7 | itoman
# Processing Record 6 of Set 7 | lundazi
# Processing Record 7 of Set 7 | maryborough
# Processing Record 8 of Set 7 | minzhu
# Processing Record 9 of Set 7 | dombarovskiy
# Processing Record 10 of Set 7 | wynyard
# Processing Record 11 of Set 7 | ngardmau
# Processing Record 12 of Set 7 | gumdag
# Processing Record 13 of Set 7 | igarka
# Processing Record 14 of Set 7 | yelizovo
# Processing Record 15 of Set 7 | caraballeda
# Processing Record 16 of Set 7 | nova vicosa
# Processing Record 17 of Set 7 | hasilpur
# Processing Record 18 of Set 7 | pahrump
# Processing Record 19 of Set 7 | tshela
# Processing Record 20 of Set 7 | palmer
# Processing Record 21 of Set 7 | mount gambier
# Processing Record 22 of Set 7 | baracoa
# Processing Record 23 of Set 7 | edson
# Processing Record 24 of Set 7 | pitanga
# Processing Record 25 of Set 7 | slutsk
# Processing Record 26 of Set 7 | nicoya
# Processing Record 27 of Set 7 | alofi
| ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 6 of Set 9 | santo antonio de jesus
# Processing Record 7 of Set 9 | daru
# Processing Record 8 of Set 9 | enriquillo
# Processing Record 9 of Set 9 | qala i naw
# Processing Record 10 of Set 9 | shiqian
# Processing Record 11 of Set 9 | bambari
# Processing Record 12 of Set 9 | callao
# Processing Record 13 of Set 9 | la rinconada
# Processing Record 14 of Set 9 | natal
# Processing Record 15 of Set 9 | crateus
# Processing Record 16 of Set 9 | ponta delgada
# Processing Record 17 of Set 9 | guerrero negro
# Processing Record 18 of Set 9 | massaguet
# Processing Record 19 of Set 9 | guiyang
# Processing Record 20 of Set 9 | puerto santa
# Processing Record 21 of Set 9 | rawson
# Processing Record 22 of Set 9 | xankandi
# Processing Record 23 of Set 9 | tarrafal de sao nicolau
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | chernyshevskiy
# Processing Record 26 of Set 9 | ibipeba
# Processing Record 27 of Set 9 | ke-macina
# Processing Record 28 of Set 9 | mahina
# Processing Record 29 of Set 9 | fabens
# Processing Record 30 of Set 9 | losal
# Processing Record 31 of Set 9 | tenno
# Processing Record 32 of Set 9 | santa terezinha
# Processing Record 33 of Set 9 | kenora
# Processing Record 34 of Set 9 | tezontepec
# Processing Record 35 of Set 9 | rurrenabaque
# Processing Record 36 of Set 9 | carutapera
# Processing Record 37 of Set 9 | niquelandia
# Processing Record 38 of Set 9 | indre arna
# Processing Record 39 of Set 9 | manoc-manoc
# Processing Record 40 of Set 9 | reggane
# Processing Record 41 of Set 9 | kidal
# Processing Record 42 of Set 9 | prince rupert
# Processing Record 43 of Set 9 | vorkuta
# Processing Record 44 of Set 9 | hoemul-li
# Processing Record 45 of Set 9 | nizhneudinsk
# Processing Record 46 of Set 9 | kaoma
# Processing Record 47 of Set 9 | vila velha
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | sovetskaya gavan'
# Processing Record 0 of Set 10 | dimako
# Processing Record 1 of Set 10 | punta del este
# Processing Record 2 of Set 10 | loreto
# Processing Record 3 of Set 10 | icano
# Processing Record 4 of Set 10 | merritt
# Processing Record 5 of Set 10 | mirnyy
# Processing Record 6 of Set 10 | tual
# Processing Record 7 of Set 10 | antalaha
# Processing Record 8 of Set 10 | tantou
# Processing Record 9 of Set 10 | kyaikkami
# Processing Record 10 of Set 10 | brewton
# Processing Record 11 of Set 10 | tolanaro
# Processing Record 12 of Set 10 | guangming
# Processing Record 13 of Set 10 | betong
# Processing Record 14 of Set 10 | aral
# Processing Record 15 of Set 10 | ankazoabo
# Processing Record 16 of Set 10 | jilin
# Processing Record 17 of Set 10 | acarau
# Processing Record 18 of Set 10 | villa la venta
# Processing Record 19 of Set 10 | ahvaz
# Processing Record 20 of Set 10 | bangar
# Processing Record 21 of Set 10 | leava
# Processing Record 22 of Set 10 | sabang
# Processing Record 23 of Set 10 | kerema
# Processing Record 24 of Set 10 | vadso
# Processing Record 25 of Set 10 | arkalyk
# Processing Record 26 of Set 10 | reyes
# Processing Record 27 of Set 10 | ust-tsilma
# Processing Record 28 of Set 10 | quellon
# Processing Record 29 of Set 10 | taperoa
# Processing Record 30 of Set 10 | yashkul'
# Processing Record 31 of Set 10 | sosnogorsk
# Processing Record 32 of Set 10 | qamdo
# Processing Record 33 of Set 10 | zhaqsy
# Processing Record 34 of Set 10 | north bend
# Processing Record 35 of Set 10 | baoqing
# Processing Record 36 of Set 10 | mahdia
# Processing Record 37 of Set 10 | porto novo
# Processing Record 38 of Set 10 | east london
# Processing Record 39 of Set 10 | olyokminsk
# Processing Record 40 of Set 10 | tostado
# Processing Record 41 of Set 10 | deschutes river woods
# Processing Record 42 of Set 10 | luderitz
# Processing Record 43 of Set 10 | abengourou
# Processing Record 44 of Set 10 | whitecourt
# Processing Record 45 of Set 10 | albertville
# Processing Record 46 of Set 10 | eraan
# Processing Record 47 of Set 10 | torghay
# Processing Record 48 of Set 10 | yumbo
# Processing Record 49 of Set 10 | jinka
# Processing Record 0 of Set 11 | tubarjal
# Processing Record 1 of Set 11 | port augusta
# Processing Record 2 of Set 11 | richards bay
# Processing Record 3 of Set 11 | belyy yar
# Processing Record 4 of Set 11 | san jose de feliciano
# Processing Record 5 of Set 11 | tianshui
# Processing Record 6 of Set 11 | ust'-kut
# Processing Record 7 of Set 11 | magdagachi
# Processing Record 8 of Set 11 | nili
# Processing Record 9 of Set 11 | vegreville
# Processing Record 10 of Set 11 | kayangel
# Processing Record 11 of Set 11 | rundu
# Processing Record 12 of Set 11 | manado
# Processing Record 13 of Set 11 | hadibu
# Processing Record 14 of Set 11 | pacific grove
# Processing Record 15 of Set 11 | colonia
# Processing Record 16 of Set 11 | khash
# Processing Record 17 of Set 11 | cocal
# Processing Record 18 of Set 11 | morondava
# Processing Record 19 of Set 11 | talara
# Processing Record 20 of Set 11 | kyzyl
# Processing Record 21 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 22 of Set 11 | yanchep
# Processing Record 23 of Set 11 | ghadamis
# Processing Record 24 of Set 11 | isangel
# Processing Record 25 of Set 11 | sao joao da barra
# Processing Record 26 of Set 11 | cole harbour
# Processing Record 27 of Set 11 | kailua-kona
# Processing Record 28 of Set 11 | thanniyam
# City not found. Skipping...
# Processing Record 29 of Set 11 | port saint john's
# Processing Record 30 of Set 11 | khilok
# Processing Record 31 of Set 11 | mansoa
# Processing Record 32 of Set 11 | ash shafa
# Processing Record 33 of Set 11 | kadnikov
# Processing Record 34 of Set 11 | mili
# Processing Record 35 of Set 11 | puerto baquerizo moreno
# Processing Record 36 of Set 11 | vallenar
# Processing Record 37 of Set 11 | huambo
# Processing Record 38 of Set 11 | kwang binh
# Processing Record 39 of Set 11 | laizhou
# Processing Record 40 of Set 11 | samana
# Processing Record 41 of Set 11 | salym
# Processing Record 42 of Set 11 | marquette
# Processing Record 43 of Set 11 | alliance
# Processing Record 44 of Set 11 | galveston
# Processing Record 45 of Set 11 | libreville
# Processing Record 46 of Set 11 | libenge
# Processing Record 47 of Set 11 | zavodskoy
# Processing Record 48 of Set 11 | esperanza
# Processing Record 49 of Set 11 | gaspra
# Processing Record 0 of Set 12 | aripuana
# Processing Record 1 of Set 12 | bahia de kino
# Processing Record 2 of Set 12 | caleta olivia
# Processing Record 3 of Set 12 | keningau
# Processing Record 4 of Set 12 | muynoq
# Processing Record 5 of Set 12 | waynesville
# Processing Record 6 of Set 12 | lompoc
# Processing Record 7 of Set 12 | ishim
# Processing Record 8 of Set 12 | la gi
# Processing Record 9 of Set 12 | san patricio
# Processing Record 10 of Set 12 | moultonborough
# Processing Record 11 of Set 12 | mweka
# Processing Record 12 of Set 12 | yeniseysk
# Processing Record 13 of Set 12 | stockton heath
# Processing Record 14 of Set 12 | itamaraca
# Processing Record 15 of Set 12 | kargasok
# Processing Record 16 of Set 12 | valparaiso
# Processing Record 17 of Set 12 | maddur
# Processing Record 18 of Set 12 | 'alaqahdari dishu
# Processing Record 19 of Set 12 | geneina
# Processing Record 20 of Set 12 | moldova noua
# Processing Record 21 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 22 of Set 12 | ishtixon shahri
# City not found. Skipping...
# Processing Record 23 of Set 12 | croix-des-bouquets
# Processing Record 24 of Set 12 | freetown
# Processing Record 25 of Set 12 | ak-dovurak
# Processing Record 26 of Set 12 | sagalo
# Processing Record 27 of Set 12 | idri
# Processing Record 28 of Set 12 | longboat key
# Processing Record 29 of Set 12 | inarajan village
# Processing Record 30 of Set 12 | paracuru
# Processing Record 31 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 12 | egilsstadir
# Processing Record 33 of Set 12 | gorontalo
# Processing Record 34 of Set 12 | hailey
# Processing Record 35 of Set 12 | labuan
# Processing Record 36 of Set 12 | mareeba
# Processing Record 37 of Set 12 | ciudad bolivar
# Processing Record 38 of Set 12 | inhambane
# Processing Record 39 of Set 12 | rudnichnyy
# Processing Record 40 of Set 12 | rio grande
# Processing Record 41 of Set 12 | shingu
# Processing Record 42 of Set 12 | happy valley-goose bay
# Processing Record 43 of Set 12 | kolonia town
# Processing Record 44 of Set 12 | bulayevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  san luis de la loma  17.2706 -100.8939     28.48        74          99
# 1          tres lagoas -20.7511  -51.6783     24.29        55          58
# 2           terra rica -22.7094  -52.6169     23.35        34           0
# 3             waitangi -43.9535 -176.5597     11.24        73          38
# 4    port-aux-francais -49.3500   70.2167      4.05        88         100
#
#    Wind Speed Country        Date
# 0        3.22      MX  1731535534
# 1        2.36      BR  1731535535
# 2        2.84      BR  1731535536
# 3        5.94      NZ  1731535227
# 4       13.51      TF  1731535212

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        san luis de la loma  17.2706 -100.8939     28.48        74
# 1                tres lagoas -20.7511  -51.6783     24.29        55
# 2                 terra rica -22.7094  -52.6169     23.35        34
# 3                   waitangi -43.9535 -176.5597     11.24        73
# 4          port-aux-francais -49.3500   70.2167      4.05        88
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        3.22      MX  1731535534
# 1                58        2.36      BR  1731535535
# 2                 0        2.84      BR  1731535536
# 3                38        5.94      NZ  1731535227
# 4               100       13.51      TF  1731535212

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# First two are the data we are sorting by - Latitude and Max Temperater while other parts are for the look of the scatter plot 
plt.scatter(city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities")
# Adding title, x-axis label, y-axis lable

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")


# Save the figure
plt.savefig("Latitude vs Max Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities")

# Incorporate the other graph properties
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")


# Save the figure
plt.savefig("Latitude vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities")

# Incorporate the other graph properties
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities")

# Incorporate the other graph properties
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
   
    # y = x*m+b
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot the formula 
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
   
    # add the line, labels, r2 value at the top and then show the graph 
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)

    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
#dataframe using the location function to set it to latitude >= 0)
northern_hemisphere_df = city_data_df.loc[(city_data_df["Lat"] >= 0),:]

# Display sample data
northern_hemisphere_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        san luis de la loma  17.2706 -100.8939     28.48        74
# 5                   thompson  55.7435  -97.8558      3.09        60
# 6                       mary  37.0000   62.5000      5.34        63
# 7               san patricio  28.0170  -97.5169     30.97        46
# 9                    montana  43.4125   23.2250      4.62        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        3.22      MX  1731535534
# 5                20        4.63      CA  1731535539
# 6                46        4.43      TM  1731535540
# 7                32        3.32      US  1731535541
# 9                99        0.85      BG  1731535544

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0) - same as above but with the latitude test updated 
southern_hemisphere_df = city_data_df.loc[(city_data_df["Lat"] < 0 ),:]

# Display sample data
southern_hemisphere_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              tres lagoas -20.7511  -51.6783     24.29        55          58
# 2               terra rica -22.7094  -52.6169     23.35        34           0
# 3                 waitangi -43.9535 -176.5597     11.24        73          38
# 4        port-aux-francais -49.3500   70.2167      4.05        88         100
# 8                     lebu -37.6167  -73.6500     13.84        80         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.36      BR  1731535535
# 2              2.84      BR  1731535536
# 3              5.94      NZ  1731535227
# 4             13.51      TF  1731535212
# 8              7.90      CL  1731535542

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (10,-10))
# Out:
# The r-value is: 0.7380730798116797

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-50,30))
# Out:
# The r-value is: 0.5143957402509572

# %% [markdown]
# **Discussion about the linear relationship:** In the northern Hemisphere, Latitude and Max Temp have a R value of .73 which means they are positively correlated. In the real world, that means you can expect higher possible temperatures as you increase in Latitude. The Southern hemisphere also has a positive correlation, however it is less strong than than the correlation in the Northern Hemisphere at .51

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (10,10))
# Out:
# The r-value is: 0.06292543194349388

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50,30))
# Out:
# The r-value is: 0.06173782049843445

# %% [markdown]
# **Discussion about the linear relationship:** Both the Northern and Southern hemisphere, have a R value that is close to 0 which means humidity and latitude have a low correlation, regardless of which hemisphere you are in.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (10,10))
# Out:
# The r-value is: 0.029853247085107903

# %%
# Southern Hemisphere
# # Linear regression on Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-50,30))
# Out:
# The r-value is: 0.0025964480270620344

# %% [markdown]
# **Discussion about the linear relationship:** At .03 and .002 respectively, the North and South hemispheres' cloudiness and latitude have a very low correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,10))
# Out:
# The r-value is: 0.03279902088923244

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50,30))
# Out:
# The r-value is: 0.06190037140254232

# %% [markdown]
# **Discussion about the linear relationship:** At .03 and .06 respectively, the North and South hemispheres' wind speed and latitude have a very low correlation.
